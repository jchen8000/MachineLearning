# %% [markdown]
# <a href="https://colab.research.google.com/github/jchen8000/MachineLearning/blob/master/Others/color_wheel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
# %matplotlib inline 

fg = plt.figure(figsize=(8,8))
ax = fg.add_axes([0.1,0.1,0.8,0.8], projection='polar')

colormap = plt.get_cmap('hsv')
norm = mpl.colors.Normalize(0.0, 2*np.pi)

n = 360  
t = np.linspace(0, 2*np.pi, n)   
r = np.linspace(0.1, 1)  
rg, tg = np.meshgrid(r, t) 
c = tg 
im = ax.pcolormesh(t, r, c.T, norm=norm, cmap=colormap) 
ax.set_yticklabels([])  
# ax.set_xticklabels([])
ax.spines['polar'].set_visible(False) 
plt.show()
