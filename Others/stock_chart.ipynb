# %% [markdown]
# <a href="https://colab.research.google.com/github/jchen8000/MachineLearning/blob/master/Others/stock_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Chart

# %%
pip install plotly==4.1.0
# Out:
# ...
#      |████████████████████████████████| 7.1MB 5.0MB/s
# ...
#   Found existing installation: plotly 3.6.1
#     Uninstalling plotly-3.6.1:
#       Successfully uninstalled plotly-3.6.1
# ...

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

df_SQQQ = pd.read_csv('https://raw.githubusercontent.com/jchen8000/MachineLearning/master/Others/data/SQQQ.csv')

df = df_SQQQ.loc[700:753, :]

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="23d59643-6a96-45d7-a2e4-f13dfc9b5371" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23d59643-6a96-45d7-a2e4-f13dfc9b5371")) {
#                     Plotly.newPlot(
#                         '23d59643-6a96-45d7-a2e4-f13dfc9b5371',
# ...

# %%
df_QQQ = pd.read_csv('https://raw.githubusercontent.com/jchen8000/MachineLearning/master/Others/data/QQQ.csv')

df = df_QQQ.loc[700:753, :]

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b90e5497-6111-434e-8b55-b4e587f72240" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b90e5497-6111-434e-8b55-b4e587f72240")) {
#                     Plotly.newPlot(
#                         'b90e5497-6111-434e-8b55-b4e587f72240',
# ...

# %%
df_SPY = pd.read_csv('https://raw.githubusercontent.com/jchen8000/MachineLearning/master/Others/data/SPY.csv')

df = df_QQQ.loc[700:753, :]

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aac42df8-17e6-44d9-b7ea-820747996ee3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aac42df8-17e6-44d9-b7ea-820747996ee3")) {
#                     Plotly.newPlot(
#                         'aac42df8-17e6-44d9-b7ea-820747996ee3',
# ...

# %%
df.loc[700:753, :]
# Out:
#            Date       Open       High  ...      Close  Adj Close    Volume
# 700  2019-06-11  36.590000  38.000000  ...  37.580002  37.315140  14132200
# 701  2019-06-12  37.930000  38.459999  ...  38.240002  37.970490  10961600
# 702  2019-06-13  37.810001  38.029999  ...  37.590000  37.325069  10710300
# 703  2019-06-14  38.230000  38.540001  ...  38.119999  37.851330   8803800
# 704  2019-06-17  37.889999  37.980000  ...  37.400002  37.136410   8756800
# 705  2019-06-18  36.099998  36.389999  ...  35.820000  35.567543  16636300
# 706  2019-06-19  35.619999  36.290001  ...  35.389999  35.140572  11127600
# 707  2019-06-20  33.939999  35.230000  ...  34.450001  34.207199  12416100
# 708  2019-06-21  34.590000  34.820000  ...  34.570000  34.326351  11394700
# 709  2019-06-24  34.430000  34.660000  ...  34.619999  34.375999   6259900
# 710  2019-06-25  34.439999  36.290001  ...  36.110001  36.110001  20328000
# ...
