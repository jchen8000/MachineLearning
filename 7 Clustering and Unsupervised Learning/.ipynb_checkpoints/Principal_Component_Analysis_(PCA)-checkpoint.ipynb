# %% [markdown]
# <a href="https://colab.research.google.com/github/jchen8000/MachineLearning/blob/master/7%20Clustering%20and%20Unsupervised%20Learning/.ipynb_checkpoints/Principal_Component_Analysis_(PCA)-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Principal Component Analysis (PCA)
#
#
# ***ABSTRACT***
#
# This is a hands-on practice of Principal Component Analysis (PCA) Algorithm. PCA is a algorithm used to reduce the number of features within a dataset.
#
# 1. Understand the PCA algorithm by randomly generating 2d sample data, apply the Sklearn PCA model for one and two compoents respectively, and visualize the sample data with PCA results.
#
# 3. Apply PCA on Boston Dataset and reduce the features in order to visualize the dataset.
#
# 2. Apply PCA for image compression, load the Eigenfaces image dataset, each image size is 47x62=2914 pixels(features), use the PCA to reduce it to less than 100 features. Then use the neural network to recognize the images.

# %% [markdown]
# ## 1. Understand Pricipal Component Analysis
#
#
# ### 1.1 PCA Algorithm
#
# $\qquad \textrm{Given training set}: x^{(1)}, x^{(2)},...,x^{(m)} \quad\in\mathbb{R}^n$
#
# 1.   Normalize the data to have a mean of 0 and standard deviation of 1.
#
# $\qquad\qquad \displaystyle x_j^{(i)}\leftarrow\displaystyle\frac{x_j^{(i)}-\mu_j}{\sigma_j}\quad$
#
# $\qquad\qquad \displaystyle\textrm{where}\quad\quad\mu_j = \frac{1}{m}\sum_{i=1}^mx_j^{(i)}\quad\quad\textrm{and}\quad\quad\sigma_j^2=\frac{1}{m}\sum_{i=1}^m(x_j^{(i)}-\mu_j)^2$
#
# 2. Compute covariance matrix,
#
# $\qquad\qquad \displaystyle\Sigma\quad=\quad\frac{1}{m}X^{T}X\quad=\quad\frac{1}{m}\sum_{i=1}^nx^{(i)}{x^{(i)}}^T\quad\in\mathbb{R}^{n\times n}$
#
# $\qquad\qquad \textrm{Note: }  \Sigma\in\mathbb{R}^{n\times n}$, it is a $n\times n$ matrix, not a summation operator here.
#
# 3. Compute eigenvectors of matrix $\Sigma$ with [Singular Value Decomposition (SVD)](https://en.wikipedia.org/wiki/Singular_value_decomposition), Python has np.linalg.svd() function to perform the calculation.
#
# $\qquad\qquad  u_1, ..., u_k\in\mathbb{R}^n$, the $k$ orthogonal principal eigenvectors of $\Sigma$, i.e. the orthogonal eigenvectors of the $k$ largest eigenvalues.
#
# 4. Project the data on
#
# $\qquad\qquad \textrm{span}_\mathbb{R}(u_1,...,u_k)$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
plt.rcParams.update({'font.size': 12})
sns.set_style('whitegrid')

# %% [markdown]
# ### 1.2 Generate a 2-D dataset, apply PCA to one component, and visualize the results

# %%
rng = np.random.RandomState(5)
#X = np.dot(rng.rand(2, 2), rng.randn(2, 100)).T
X = rng.rand(100, 2)

pca = PCA(1)
X_pca = pca.fit_transform(X)
X_reverse = pca.inverse_transform(X_pca)


fig, ax = plt.subplots(1, 2, figsize=(16, 6))
#fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.5)


ax[0].scatter(X[:, 0], X[:, 1], label='Original data', c='blue')
ax[0].scatter(X_reverse[:, 0], X_reverse[:, 1], label='PCA components', c='orange')
[ax[0].plot([X[i, 0], X_reverse[i, 0]], [X[i, 1], X_reverse[i, 1]], c='g', linestyle='dashed', linewidth=0.7 ) for i in range(X.shape[0])]
ax[0].legend(frameon=True,loc='upper left')
ax[0].axis('equal');
ax[0].set(title='Original data is mapped to the 1D PCA component')
ax[0].set_xlim((-0.2,1.2))
ax[0].set_ylim((-0.2,1.2))

ax[1].scatter(X_reverse[:, 0], X_reverse[:,1], label='Inverse Transformed data', c='orange')
ax[1].legend(frameon=True,loc='upper left')
ax[1].axis('equal');
ax[1].set(title='PCA data (1D) is transformed back to original dimensional space')
ax[1].set_xlim((-0.2,1.2))
ax[1].set_ylim((-0.2,1.2))

plt.show()

# %% [markdown]
# ### 1.3 Generate a random dataset, and apply PCA to two components, and visualize the results

# %%
rng = np.random.RandomState(2)
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T
#X = np.random.rand(200, 2)

plt.figure(1, figsize=(8,6))
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal')
plt.show()

# %%
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
print("Components_:\n", pca.components_)
print("Explained variance:\n", pca.explained_variance_)
# Out:
# Components_:
#  [[ 0.51517079  0.85708754]
#  [-0.85708754  0.51517079]]
# Explained variance:
#  [0.67663501 0.05315297]

# %%
def draw_vector(v0, v1, ax=None):
    ax.quiver(v0[0], v0[1], v1[0], v1[1], color=['r','b','g'], scale=16)


fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.5)

# plot data
ax[0].scatter(X[:, 0], X[:, 1])
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * np.sqrt(length) * 8
    draw_vector(pca.mean_, pca.mean_ + v, ax=ax[0])
ax[0].axis('equal');
ax[0].set(xlabel='x', ylabel='y', title='Input Data')

# plot principal components
X_pca = pca.transform(X)
ax[1].scatter(X_pca[:, 0], X_pca[:, 1])
draw_vector([0, 0], [0, 3], ax=ax[1])
draw_vector([0, 0], [3, 0], ax=ax[1])
ax[1].axis('equal')
ax[1].set(xlabel='component 1', ylabel='component 2',
          title='Data Transformed to Principal Components',
          xlim=(-5, 5), ylim=(-3, 3.1))
plt.show()

# %% [markdown]
# ## 2. Dimension Reduction for Visualization of Boston Dataset

# %% [markdown]
# ### 2.1 Load Boston Dataset

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
print(boston.keys())
print(boston.data.shape)
print(boston.feature_names)
print(boston.DESCR)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])
# (506, 13)
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
bos = pd.DataFrame(boston.data)
bos.columns = boston.feature_names
bos['PRICE'] = boston.target
print(bos.head())
print(bos.describe())

bos = bos.loc[bos["PRICE"] < 50.0]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       PRICE
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(bos, 
                 x_vars=boston.feature_names,
                 y_vars=["PRICE"])
plt.show()

# %% [markdown]
# ### 2.2. Dimension Reduction for Visualization
#
# From the dataset description we understand that there are 13 features. We want to visualize the PRICE in a two-dimensional space, the PRICE is in y-axis, so we want to reduce multiple features into one-dimensional as x_axis.

# %% [markdown]
# ***2.2.1 PCA 1***
#
# We will reduce five features --  "CRIM","NOX","TAX","DIS","LSTAT" into one dimension, and visualize it with Price in a 2-D plot.

# %%
pca_features = ["CRIM","NOX","TAX","DIS","LSTAT"]
X = bos.loc[:, pca_features].values
y = bos.loc[:,["PRICE"]].values

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X = sc.fit_transform(X)

# %%
pca = PCA(n_components=1)
X_pca = pca.fit_transform(X)
pca.explained_variance_ratio_
# Out:
# array([0.64579306])

# %%
fig = plt.figure(1, figsize=(10,8))

ax = sns.regplot(x=X_pca, y=y.reshape(y.shape[0]), 
                 scatter_kws={"color": "blue"}, 
                 line_kws={"color": "red"})
ax.set_title( "Prices vs Reduced Dimension", fontsize=20 )
ax.set_ylabel("PRICE", fontsize=16)
ax.set_xlabel("Dimension reduced from %s" % pca_features, fontsize=16)
ax.grid(True)

plt.show()

# %% [markdown]
# ***2.2.2 PCA 2***
#
# Similarly we will reduce three features -- "RM","B","ZN" into one dimension, and visualize it with Price in a 2-D plot.

# %%
pca_features = ["RM","B","ZN"]
X = bos.loc[:, pca_features].values
y = bos.loc[:,["PRICE"]].values

sc = StandardScaler()
X = sc.fit_transform(X)

# %%
pca = PCA(n_components=1)
X_pca = pca.fit_transform(X)
pca.explained_variance_ratio_
# Out:
# array([0.47197264])

# %%
fig = plt.figure(1, figsize=(10,8))

ax = sns.regplot(x=X_pca, y=y.reshape(y.shape[0]), 
                 scatter_kws={"color": "blue"}, 
                 line_kws={"color": "red"})
ax.set_title( "Prices vs Reduced Dimension", fontsize=20 )
ax.set_ylabel("PRICE", fontsize=16)
ax.set_xlabel("Dimension reduced from %s" % pca_features, fontsize=16)
ax.grid(True)

plt.show()

# %% [markdown]
# ## 3. Principal Component Analysis (PCA) for Image Compression
#
#
# https://pythonmachinelearning.pro/face-recognition-with-eigenfaces/

# %% [markdown]
# ### 3.1 Load Eigenfaces dataset

# %%
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split

# Load data
lfw_dataset = fetch_lfw_people(min_faces_per_person=100)

_, h, w = lfw_dataset.images.shape
X = lfw_dataset.data
y = lfw_dataset.target
target_names = lfw_dataset.target_names

# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print("Total Images:", X.shape[0])
print("Image size:", w, "by", h)
# Out:
# Total Images: 1140
# Image size: 47 by 62

# %% [markdown]
# ### 3.2 Apply PCA
# Each original image is 47x62=2914 pixels, which means each image has 2914 features, we will use PCA to compress it down to less features.

# %%
# Compute a PCA 
n_components = 80
pca = PCA(n_components=n_components, whiten=True).fit(X_train)
 
# apply PCA transformation
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
print( "Original image size:", X_train.shape[1])
print( "PCA'ed image size:", X_train_pca.shape[1])
print( "Information retained after PCA transform from 2914 pixels to", n_components, "features is:", pca.explained_variance_ratio_.sum() )
# Out:
# Original image size: 2914
# PCA'ed image size: 80
# Information retained after PCA transform from 2914 pixels to 80 features is: 0.90239525

# %% [markdown]
# ### 3.3 Train the Neural Network
#
# Then we will define a neural network using sklearn.newral_network libraries, and train the neural network with the PCA'ed image dataset.

# %%
# train a neural network
from sklearn.neural_network import MLPClassifier

print("Fitting the classifier to the training set")
clf = MLPClassifier(hidden_layer_sizes=(1024,), batch_size=256, verbose=True, early_stopping=True).fit(X_train_pca, y_train)
# Out:
# Fitting the classifier to the training set
# Iteration 1, loss = 1.48805684
# Validation score: 0.512500
# Iteration 2, loss = 1.12839573
# Validation score: 0.512500
# Iteration 3, loss = 0.91561637
# Validation score: 0.625000
# Iteration 4, loss = 0.73597092
# Validation score: 0.700000
# Iteration 5, loss = 0.58204446
# Validation score: 0.775000
# Iteration 6, loss = 0.47337173
# Validation score: 0.800000
# Iteration 7, loss = 0.39097819
# Validation score: 0.812500
# Iteration 8, loss = 0.32556068
# Validation score: 0.812500
# Iteration 9, loss = 0.27272489
# Validation score: 0.800000
# Iteration 10, loss = 0.23031222
# Validation score: 0.800000
# Iteration 11, loss = 0.19560653
# Validation score: 0.800000
# Iteration 12, loss = 0.16819533
# Validation score: 0.812500
# Iteration 13, loss = 0.14515391
# Validation score: 0.812500
# Iteration 14, loss = 0.12673248
# Validation score: 0.812500
# Iteration 15, loss = 0.11075891
# Validation score: 0.812500
# Iteration 16, loss = 0.09771630
# Validation score: 0.825000
# Iteration 17, loss = 0.08649632
# Validation score: 0.825000
# Iteration 18, loss = 0.07717275
# Validation score: 0.825000
# Iteration 19, loss = 0.06954838
# Validation score: 0.825000
# Iteration 20, loss = 0.06252193
# Validation score: 0.837500
# Iteration 21, loss = 0.05664183
# Validation score: 0.837500
# Iteration 22, loss = 0.05144093
# Validation score: 0.837500
# Iteration 23, loss = 0.04702535
# Validation score: 0.825000
# Iteration 24, loss = 0.04318348
# Validation score: 0.825000
# Iteration 25, loss = 0.03985234
# Validation score: 0.825000
# Iteration 26, loss = 0.03684050
# Validation score: 0.825000
# Iteration 27, loss = 0.03423345
# Validation score: 0.825000
# Iteration 28, loss = 0.03193721
# Validation score: 0.825000
# Iteration 29, loss = 0.02982202
# Validation score: 0.825000
# Iteration 30, loss = 0.02788097
# Validation score: 0.825000
# Iteration 31, loss = 0.02621601
# Validation score: 0.825000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
from sklearn.metrics import classification_report

y_pred = clf.predict(X_test_pca)
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                    precision    recall  f1-score   support
#
#      Colin Powell       0.85      0.85      0.85        66
#   Donald Rumsfeld       0.84      0.66      0.74        41
#     George W Bush       0.87      0.92      0.90       169
# Gerhard Schroeder       0.81      0.96      0.88        27
#        Tony Blair       0.85      0.72      0.78        39
#
#         micro avg       0.86      0.86      0.86       342
#         macro avg       0.84      0.82      0.83       342
#      weighted avg       0.86      0.86      0.85       342

# %% [markdown]
# ### 3.4 Visualize the image data with true and predicted values

# %%
# Visualization
def plot_gallery(images, titles, h, w, rows=5, cols=10):
    plt.figure(figsize=(16,12))
    plt.subplots_adjust(wspace=0.1, hspace=0.3)
    for i in range(rows * cols):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        if titles is not None:
            plt.title(titles[i])
        plt.xticks(())
        plt.yticks(())

def titles(y_pred, y_test, target_names):
    for i in range(y_pred.shape[0]):
        pred_name = target_names[y_pred[i]].split(' ')[-1]
        true_name = target_names[y_test[i]].split(' ')[-1]
        yield 'pred: {0}\ntrue: {1}'.format(pred_name, true_name)        

prediction_titles = list(titles(y_pred, y_test, target_names))        
plot_gallery(X_test, prediction_titles, h, w)

# %% [markdown]
# ### 3.5 Revers the PCA'ed images back to their original size, and visualize them
#
# We will notice that the PCA'ed images have about 90% information retained, compared with above original images.
#
# The exact information retain rate can be obtained by:
#
# > *pca.explained_variance_ratio_.sum()*, or
#
# > *pca.explained_variance_ratio_.cumsum()*

# %%
X_test_pca_reverse = pca.inverse_transform(X_test_pca)
plot_gallery(X_test_pca_reverse, prediction_titles, h, w)
